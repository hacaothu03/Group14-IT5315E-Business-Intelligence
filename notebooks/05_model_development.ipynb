# %% [markdown]
# # Module 5 - Model Development
#
# Run the command-line training pipeline from the notebook so Kaggle and local behavior stay aligned.

# %%
from pathlib import Path
import subprocess
import sys

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
cmd = [sys.executable, str(ROOT / 'scripts' / 'train_models.py'), '--include-context-features', 'false']
subprocess.run(cmd, cwd=ROOT, check=True)

# %%
import pandas as pd

pd.read_csv(ROOT / 'outputs' / 'metrics_summary.csv')

# %%
pd.read_csv(ROOT / 'outputs' / 'ablation_results.csv')
